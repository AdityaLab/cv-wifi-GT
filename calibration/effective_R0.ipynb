# %%
import pandas as pd
import numpy as np

# %%
path = '/cv19wifi/tmp/network_modeling/simulation_output/calibration_output/berkeley_all_2020-08-17_p:0.04071795_I_asym:0.004799_alpha:0.029957_simu.pkl'
df = pd.read_pickle(path)

# %%
df
# Out:
#           R0        SIRD  asymptomatic     exposed  external_inf    infected  \
# 0   0.000000    0.000000      0.000000    0.000000      0.000000    0.000000
# 1   1.142698    0.000000    109.066667    5.400000      0.000000  111.666667
# 2   1.278353  109.066667      0.000000   45.866667     37.800000   45.600000
# 3   1.278353    0.000000      0.000000   87.533333     79.533333   87.333333
# 4   1.278353    0.000000      0.000000  122.000000    114.000000  121.800000
# 5   1.278353    0.000000      0.000000  164.866667    157.000000  164.800000
# 6   1.278353    0.000000      0.000000  193.933333    186.066667  193.866667
# 7   1.278353   28.266667     14.666667  164.400000    199.466667  207.200000
# 8   1.259893   29.400000     29.666667  143.400000    219.333333  230.533333
# 9   1.247305   37.533333     26.600000  130.333333    234.000000  236.600000
# 10  1.242734   42.666667     26.933333  127.533333    266.466667  259.066667
# ...

# %%
np.max(df.iloc[7:22]['R0'])
# Out:
# 1.2783527583527585

# %%
np.min(df.iloc[7:22]['R0'])
# Out:
# 1.2359519444993832
